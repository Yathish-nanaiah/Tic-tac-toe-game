# %%
import numpy

# %%
import numpy as np


def des():
    print("positions")
    print("That is")
    print("00  -1st position")
    print("01  -2nd position")
    print("02  -3rd position")
    print("10  -4th position")
    print("11  -5th position")
    print("12  -6th position")
    print("21  -7th position")
    print("22  -8th position")
    print("23  -9th position")
    b=np.array([["00","01","02"],["10","11","12"],["20","21","22"]])
    print([a[0][0],a[0][1],a[0][2]],    [b[0][0],b[0][1],b[0][2]])
    print([a[1][0],a[1][1],a[1][2]],    [b[1][0],b[1][1],b[1][2]])
    print([a[2][0],a[2][1],a[2][2]],    [b[2][0],b[2][1],b[2][2]])
    
def insertX(m):  
    if(m=="00"):
        a[0][0]="x"
        print(a)
    elif(m=="01"):
        a[0][1]="x"
        print(a)
    elif(m=="02"):
        a[0][2]="x"
        print(a)
    elif(m=="10"):
        a[1][0]="x"
        print(a)
    elif(m=="11"):
        a[1][1]="x"
        print(a)
    elif(m=="12"):
        a[1][2]="x"
        print(a)
    elif(m=="20"):
        a[2][0]="x"
        print(a)
    elif(m=="21"):
        a[2][1]="x"
        print(a)
    elif(m=="22"):
        a[2][2]="x"
        print(a)
    else: 
        pass
        
def insertO(m): 
        if(m=="00"):
            a[0][0]="o"
            print(a)
        elif(m=="01"):
            a[0][1]="o"
            print(a)
        elif(m=="02"):
            a[0][2]="o"
            print(a)
        elif(m=="10"):
            a[1][0]="o"
            print(a)
        elif(m=="11"):
            a[1][1]="o"
            print(a)
        elif(m=="12"):
            a[1][2]="o"
            print(a)
        elif(m=="20"):
            a[2][0]="o"
            print(a)
        elif(m=="21"):
            a[2][1]="o"
            print(a)
        elif(m=="22"):
            a[2][2]="o"
            print(a)
        else:
            print("invalid position")

def res(m):
    if(m=="00"):
        if(a[0][0]==a[1][1]==a[2][2]):
            print("You win")
            z=5
            return z
        elif(a[0][0]==a[1][0]==a[2][0]):
            print("You win")
            z=5
            return z
        elif(a[0][0]==a[0][1]==a[0][2]):
            print("You win")
            z=5
            return z
        else:
            pass
    elif(m=="01"):
        if(a[0][1]==a[1][1]==a[2][1]):
            print("You win")
            z=5
            return z
        elif(a[0][1]==a[0][0]==a[0][2]):
            print("You win")
            z=5
            return z
        else:
            pass
    elif(m=="02"):
        if(a[0][2]==a[1][2]==a[2][2]):
            print("You win")
            z=5
            return z
        elif(a[0][2]==a[1][1]==a[2][0]):
            print("You win")
            z=5
            return z
        elif(a[0][0]==a[0][1]==a[0][2]):
            print("You win")
            z=5
            return z
        else:
            pass
    elif(m=="10"):
        if(a[0][0]==a[1][0]==a[2][0]):
            print("You win")
            z=5
            return z
        elif(a[1][0]==a[1][1]==a[1][2]):
            print("You win")
            z=5
            return z
        else:
            pass
    elif(m=="11"):
        if(a[0][0]==a[1][1]==a[2][2]):
            print("You win")
            z=5
            return z
        elif(a[2][0]==a[1][1]==a[0][2]):
            print("You win")
            z=5
            return z
        elif(a[1][0]==a[1][1]==a[1][2]):
            print("You win")
            z=5
            return z
        elif(a[0][1]==a[1][1]==a[2][1]):
            print("You win")
            z=5
            return z
        else:
            pass
    elif(m=="12"):
        if(a[0][2]==a[1][2]==a[2][2]):
            print("You win")
            z=5
            return z
        elif(a[1][0]==a[1][1]==a[1][2]):
            print("You win")
            z=5
            return z
        else:
            pass
    elif(m=="20"):
        if(a[0][0]==a[1][0]==a[2][0]):
            print("You win")
            z=5
            return z
        elif(a[0][2]==a[1][1]==a[2][0]):
            print("You win")
            z=5
            return z
        elif(a[2][0]==a[2][1]==a[2][2]):
            print("You win")
            z=5
            return z
        else:
            pass
    elif(m=="21"):
        if(a[0][1]==a[1][1]==a[2][1]):
            print("You win")
            z=5
            return z
        elif(a[2][0]==a[2][1]==a[2][2]):
            print("You win")
            z=5
            return z
        else:
            pass
    elif(m=="22"):
        if(a[0][2]==a[1][2]==a[2][2]):
            print("You win")
            z=5
            return z
        elif(a[0][0]==a[1][1]==a[2][2]):
            print("You win")
            z=5
            return z
        elif(a[2][0]==a[2][1]==a[2][2]):
            print("You win")
            z=5
            return z
        else:
            pass
    else:
        pass

# %%
y=input("enter X or O: ")
#y="x"
#y="o"
if(y=="x" or y=="X"):
    print("userA is X and userB is O")
    A=1
    B=2
else:
    print("userA is O and userB is X")
    A=2
    B=1

    
a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
print(a)
#print("A=",A)
#print("B=",B)
s=0
while(A==1 and B==2):
    i=0
    while(i<10):
        while(s!=5 and i<9):
            if(s==5):
                a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
            else:
                print("Enter position to insert X:")
                des()
                m=input()
                insertX(m)
                s=res(m)
                i=i+1
                pass
            if(i==9):
                continue
            if(s==5):
                a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
                break
            else:
                print("Enter position to insert O:")
                des()
                m=input()
                insertO(m)
                s=res(m)
                i=i+1
                continue
        if(i==9):
            print("game tied")
            i=i+1
        break
        
    s=0
    print("play again?")
    k=input("yes or no: ")
    if(k=="yes"):
        a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
        pass
    elif(k=="no"):
        a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
        break
    else:
        pass
    i=0
    while(i<10):
        while(s!=5 and i<9):
            if(s==5):
                a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
                break
            else:
                print("Enter position to insert O:")
                des()
                m=input()
                insertO(m)
                s=res(m)
                i=i+1
                pass
            if(i==9):
                continue
            if(s==5):
                a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
                break
            else:
                print("Enter position to insert X:")
                des()
                m=input()
                insertX(m)
                s=res(m)
                i=i+1
                continue
        if(i==9):
            print("game tied")
            i=i+1
        break   
    s=0
    print("start game?")
    k=input("yes or no: ")
    if(k=="yes"):
        a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
        continue
    elif(k=="no"):
        a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
        break
    else:
        pass
        
while(A==2 and B==1):
    i=0
    while(i<10):
        while(s!=5 and i<9):
            if(s==5):
                a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
                break
            else:
                print("Enter position to insert O:")
                des()
                m=input()
                insertO(m)
                s=res(m)
                i=i+1
                pass
            if(i==9):
                continue
            if(s==5):
                a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
            else:
                print("Enter position to insert X:")
                des()
                m=input()
                insertX(m)
                s=res(m)
                i=i+1
                continue
        if(i==9):
            print("game tied")
            i=i+1
        break
    s=0
    print("start game?")
    k=input("yes or no: ")
    if(k=="yes"):
        a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
        pass
    elif(k=="no"):
        a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
        break
    else:
        pass
    i=0
    while(i<10):
        while(s!=5 and i<9):
            if(s==5):
                a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
                break
            else:
                print("Enter position to insert X:")
                des()
                m=input()
                insertX(m)
                s=res(m)
                i=i+1
                pass
            if(i==9):
                continue
            if(s==5):
                a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
                break
            else:
                print("Enter position to insert O:")
                des()
                m=input()
                insertO(m)
                s=res(m)
                i=i+1
                continue
        if(i==9):
            print("game tied")
            i=i+1
        break   
    s=0
    print("play again?")
    k=input("yes or no: ")
    if(k=="yes"):
        
        a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
        continue
    elif(k=="no"):
        a=np.array([[" "," "," "],[" "," "," "],[" "," "," "]])
        break
    else:
        pass
# Out:
# enter X or O: o
# userA is O and userB is X
# [[' ' ' ' ' ']
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']]
# Enter position to insert O:
# positions
# That is
# 00  -1st position
# 01  -2nd position
# 02  -3rd position
# 10  -4th position
# 11  -5th position
# 12  -6th position
# 21  -7th position
# 22  -8th position
# 23  -9th position
# [' ', ' ', ' '] ['00', '01', '02']
# [' ', ' ', ' '] ['10', '11', '12']
# [' ', ' ', ' '] ['20', '21', '22']
# 00
# [['o' ' ' ' ']
#  [' ' ' ' ' ']
#  [' ' ' ' ' ']]
# Enter position to insert X:
# positions
# That is
# 00  -1st position
# 01  -2nd position
# 02  -3rd position
# 10  -4th position
# 11  -5th position
# 12  -6th position
# 21  -7th position
# 22  -8th position
# 23  -9th position
# ['o', ' ', ' '] ['00', '01', '02']
# [' ', ' ', ' '] ['10', '11', '12']
# [' ', ' ', ' '] ['20', '21', '22']
# 11
# [['o' ' ' ' ']
#  [' ' 'x' ' ']
#  [' ' ' ' ' ']]
# Enter position to insert O:
# positions
# That is
# 00  -1st position
# 01  -2nd position
# ...
